# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')
summer = pd.read_csv('summer.csv')

# %% [markdown]
# ## Sort dataframe

# %%
titanic.age.sort_values()
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: age, Length: 891, dtype: float64

# %%
# Does not change actual dataframe
titanic.sort_values(by="age")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by="age",ascending=False,inplace=True)

# %%
titanic.head()
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 630         1       1  male  80.0      0      0  30.0000        S    A
# 851         0       3  male  74.0      0      0   7.7750        S  NaN
# 493         0       1  male  71.0      0      0  49.5042        C  NaN
# 96          0       1  male  71.0      0      0  34.6542        C    A
# 116         0       3  male  70.5      0      0   7.7500        Q  NaN

# %%
titanic.sort_values(by=["age","sex", "pclass"],ascending=False,inplace=True)

# %%
titanic.head()
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 630         1       1  male  80.0      0      0  30.0000        S    A
# 851         0       3  male  74.0      0      0   7.7750        S  NaN
# 493         0       1  male  71.0      0      0  49.5042        C  NaN
# 96          0       1  male  71.0      0      0  34.6542        C    A
# 116         0       3  male  70.5      0      0   7.7500        Q  NaN

# %%
titanic.sort_values(by=["age","sex", "pclass"],ascending=[False,True,False],inplace=True)

# %%
titanic.head()
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked deck
# 630         1       1  male  80.0      0      0  30.0000        S    A
# 851         0       3  male  74.0      0      0   7.7750        S  NaN
# 493         0       1  male  71.0      0      0  49.5042        C  NaN
# 96          0       1  male  71.0      0      0  34.6542        C    A
# 116         0       3  male  70.5      0      0   7.7500        Q  NaN

# %% [markdown]
# ## sort index

# %%
titanic.sort_index(ascending=False, inplace=True)

# %%
titanic.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 890         0       3    male  32.0      0      0   7.75        Q  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 886         0       2    male  27.0      0      0  13.00        S  NaN

# %%
titanic.sort_values(by='age').head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN

# %%
titanic.sort_values(by='age',ignore_index=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           1       3    male  0.42      0      1   8.5167        C  NaN
# 1           1       2    male  0.67      1      1  14.5000        S  NaN
# 2           1       3  female  0.75      2      1  19.2583        C  NaN
# 3           1       3  female  0.75      2      1  19.2583        C  NaN
# 4           1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       3    male   NaN      0      0   7.2292        C  NaN
# 887         0       3  female   NaN      8      2  69.5500        S  NaN
# 888         0       3    male   NaN      0      0   9.5000        S  NaN
# 889         0       3    male   NaN      0      0   7.8958        S  NaN
# 890         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# ## Rank

# %%
titanic["fare_rank"] = titanic.fare.rank(method='min',ascending=False)

# %%
titanic.sort_values("fare",ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 341         1       1  female  24.0      3      2  263.0000        S    C
# 438         0       1    male  64.0      1      4  263.0000        S    C
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 277         0       2    male   NaN      0      0    0.0000        S  NaN
# 633         0       1    male   NaN      0      0    0.0000        S  NaN
# 302         0       3    male  19.0      0      0    0.0000        S  NaN
# 597         0       3    male  49.0      0      0    0.0000        S  NaN
# 271         1       3    male  25.0      0      0    0.0000        S  NaN
#
#      fare_rank
# 679        1.0
# 258        1.0
# 737        1.0
# ...

# %% [markdown]
# ## nunique() and nlarges()/nsmalles()

# %%
titanic.nunique()
# Out:
# survived       2
# pclass         3
# sex            2
# age           88
# sibsp          7
# parch          7
# fare         248
# embarked       3
# deck           7
# fare_rank    248
# dtype: int64

# %%
titanic.nunique(dropna=False)
# Out:
# survived       2
# pclass         3
# sex            2
# age           89
# sibsp          7
# parch          7
# fare         248
# embarked       4
# deck           8
# fare_rank    248
# dtype: int64

# %%
titanic.nlargest(n=5,columns='fare' )
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 438         0       1    male  64.0      1      4  263.0000        S    C
# 341         1       1  female  24.0      3      2  263.0000        S    C
#
#      fare_rank
# 737        1.0
# 679        1.0
# 258        1.0
# 438        4.0
# 341        4.0

# %%
titanic.nsmallest(n=10, columns='age')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 803         1       3    male  0.42      0      1    8.5167        C  NaN
# 755         1       2    male  0.67      1      1   14.5000        S  NaN
# 644         1       3  female  0.75      2      1   19.2583        C  NaN
# 469         1       3  female  0.75      2      1   19.2583        C  NaN
# 831         1       2    male  0.83      1      1   18.7500        S  NaN
# 78          1       2    male  0.83      0      2   29.0000        S  NaN
# 305         1       1    male  0.92      1      2  151.5500        S    C
# 827         1       2    male  1.00      0      2   37.0042        C  NaN
# 788         1       3    male  1.00      1      2   20.5750        S  NaN
# 386         0       3    male  1.00      5      2   46.9000        S  NaN
#
#      fare_rank
# 803      598.0
# 755      435.0
# 644      381.0
# 469      381.0
# 831      387.0
# 78       249.0
# 305       26.0
# 827      191.0
# ...

# %% [markdown]
# ## Correlation

# %%
titanic.corr()
# Out:
#            survived    pclass       age     sibsp     parch      fare  \
# survived   1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass    -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age       -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp     -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch      0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare       0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# fare_rank -0.322046  0.700150 -0.116334 -0.357585 -0.366020 -0.639490
#
#            fare_rank
# survived   -0.322046
# pclass      0.700150
# age        -0.116334
# sibsp      -0.357585
# parch      -0.366020
# fare       -0.639490
# fare_rank   1.000000

# %% [markdown]
# ## agg()

# %%
titanic.agg('mean')
# OR
# titanic.mean
# Out:
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# fare_rank    439.961841
# dtype: float64

# %%
titanic.agg(["mean","median","sum"])
# Out:
#           survived       pclass  \
# mean      0.383838     2.308642
# median    0.000000     3.000000
# sum     342.000000  2057.000000
#
#                                                       sex           age  \
# mean                                                  NaN     29.699118
# median                                                NaN     28.000000
# sum     malemalefemalefemalemalefemalemalemalefemalema...  21205.170000
#
#              sibsp       parch          fare      fare_rank
# mean      0.523008    0.381594     32.204208     439.961841
# median    0.000000    0.000000     14.454200     445.000000
# sum     466.000000  340.000000  28693.949300  392006.000000

# %%
titanic.agg({"survived":"mean", "age":["min","max"]})
# Out:
#       survived    age
# max        NaN  80.00
# mean  0.383838    NaN
# min        NaN   0.42

# %% [markdown]
# ## apply(),map() abd applymap()

# %%
sales = pd.read_csv('sales.csv',index_col=0)
sales.head()
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.min(axis=0)
# Out:
# Mon    17.0
# Tue     9.0
# Wed    15.0
# Thu     8.0
# Fri     7.0
# dtype: float64

# %%
sales.min(axis=1)
# Out:
# Steven    15.0
# Mike       9.0
# Andi       8.0
# Paul       7.0
# dtype: float64

# %%
def range(series):
    return (series.max() - series.min())

# %%
sales.apply(range, axis=0)
# Out:
# Mon    70.0
# Tue    58.0
# Wed    59.0
# Thu    79.0
# Fri    26.0
# dtype: float64

# %%
sales.apply(range, axis=1)
# Out:
# Steven    19.0
# Mike      78.0
# Andi      46.0
# Paul      80.0
# dtype: float64

# %%
sales.apply(lambda x: x.max()-x.min(),axis=0)
# Out:
# Mon    70.0
# Tue    58.0
# Wed    59.0
# Thu    79.0
# Fri    26.0
# dtype: float64

# %%
summer = pd.read_csv('summer.csv')
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer['Athlete'].apply(lambda x:x.split(',')[0])
# Out:
# 0             HAJOS
# 1        HERSCHMANN
# 2            DRIVAS
# 3         MALOKINIS
# 4          CHASAPIS
#             ...
# 31160    JANIKOWSKI
# 31161        REZAEI
# 31162        TOTROV
# 31163    ALEKSANYAN
# 31164       LIDBERG
# Name: Athlete, Length: 31165, dtype: object

# %%
summer['Athlete'].map(lambda x:x.split()[0])
# Out:
# 0             HAJOS,
# 1        HERSCHMANN,
# 2            DRIVAS,
# 3         MALOKINIS,
# 4          CHASAPIS,
#             ...
# 31160    JANIKOWSKI,
# 31161        REZAEI,
# 31162        TOTROV,
# 31163    ALEKSANYAN,
# 31164       LIDBERG,
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.loc[:, ["Athlete","Country"]].apply(lambda x:x[0])
# Out:
# Athlete    HAJOS, Alfred
# Country              HUN
# dtype: object

# %% [markdown]
# ### applymap() method only works on a pandas dataframe where function is applied on every element individually.
#
# ### apply() method can be applied both to series and dataframes where function can be applied both series and individual elements based on the type of function provided.
#
# ### map() method only works on a pandas series where type of operation to be applied depends on argument passed as a function, dictionary or a list.
